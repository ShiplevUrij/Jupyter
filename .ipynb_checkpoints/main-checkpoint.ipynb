# %%
import math
from sympy  import *
from sympy.plotting import plot


x = Symbol(' x ')

f1 = -12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30
f1
# Out:
# -12* x **4*sin(cos( x )) - 18* x **3 + 5* x **2 + 10* x  - 30

# %%
fun=plot(f1, show=False)
fun.show()
